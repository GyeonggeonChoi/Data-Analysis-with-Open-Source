# %% [markdown]
# <a href="https://colab.research.google.com/github/GyeonggeonChoi/Data-Analysis-with-Open-Source/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EA%B8%B0%EC%B4%88_3%EA%B0%95_%EC%8B%A4%EC%8A%B5(%EC%9B%90%EB%B3%B8)_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3강 파이썬의 이해 - 실습

# %% [markdown]
# ## 3강 1절 - 데이터 타입과 변수

# %%
53000000
# Out:
# 53000000

# %%
print("Hello World")
print("Python is fun!")
# Out:
# Hello World
# Python is fun!

# %%
print(1 / 3 * 3.14 * 10 * 10 * 24)
print(3.14 * 10 * 10 + 3.14 * 10 * 26)
# Out:
# 2512.0
# 1130.4

# %% [markdown]
# ## 3강 2절 - 연산자

# %%
# 2 ** 10, 5 / 2 vs 5 // 2, 25 % 7, 8.4 % 0.9, number % 2
print(2**10)
print (5 / 2)
print(5 // 2)
print(25 % 7)
print(8.4 % 0.9)
number = 42
print(number % 2)
# Out:
# 1024
# 2.5
# 2
# 4
# 0.30000000000000016
# 0

# %%
# max(2, 3, 4), min(2, 3, 4), round(3.141592, 2), round(3.415), abs(-3), pow(2, 3)
pow(2, 0.5)
# Out:
# 1.4142135623730951

# %%
# 원뿔의 높이와 반지름을 활용하여 부피와 겉넓이를 계산하는 프로그램
rad = 10
hei = 24
sla = pow(rad ** 2 + hei ** 2, 0.5)
# 부피 출력
print(1 / 3 * 3.14 * rad ** 2 * hei)
# 겉넓이 출력
print(3.14 * rad ** 2 + 3.14 * rad * sla)
# Out:
# 2512.0
# 1130.4

# %% [markdown]
# ## 3강 3절 - 파이썬 기초문법 상식

# %%
# 평균학점 계산 : 계산 방법 sum(수강점수) / 이수학점
print((4.5 * 2 + 4.0 * 3) / (130 - 66))
# Out:
# 0.328125

# %%
# 새로운 코드블럭 : shift Enter
